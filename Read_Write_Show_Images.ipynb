# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojKumarTiwari/OpenCV/blob/master/Read_Write_Show_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
# image matrix
img = cv2.imread("/content/drive/My Drive/ImageDatasets/PetImages/Dog/12464.jpg",0)
print(img)
# Out:
# [[248 255 242 ... 245 245 244]
#  [251 255 237 ... 245 245 244]
#  [255 253 234 ... 245 245 244]
#  ...
#  [241 241 240 ... 255 255 255]
#  [242 242 241 ... 254 254 254]
#  [244 243 241 ... 254 254 254]]

# %%
# show image
# cv2.imshow('image', img)

# %% [markdown]
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=500x333 at 0x7F6720634588>

# %%
# save image
cv2.imwrite("12464_0.png", img)
# Out:
# True
